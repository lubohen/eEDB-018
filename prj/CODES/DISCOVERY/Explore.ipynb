# %%
import pandas as pd

DIRBASE=r"C:\Users\luboh\OneDrive\Área de Trabalho\USP\EngDadosBigData\eEDB-018_REPO\DEVELOPER\eEDB-018\prj\DATA"

df1=DIRBASE + r"\all_features.csv"

# %%
allfeatures = pd.read_csv(df1)

df2=DIRBASE + r"\all_features_decorrelated.csv"
allfeatures_dec = pd.read_csv(df2)

df2=DIRBASE + r"\all_features_decorrelated.csv"
allfeatures_dec = pd.read_csv(df2)

df2=DIRBASE + r"\all_features_decorrelated.csv"
allfeatures_dec = pd.read_csv(df2)

# %%
allfeatures.head()
#allfeatures_dec.head()
# Out:
#          IDSong     F0001     F0002     F0003   F0004    F0005     F0006  \
# 0  MT0000004637  0.057377  0.056769  1.414500  4.1937  0.26533  0.000043
# 1  MT0000011357  0.178900  0.083201  0.025491  2.6400  0.43033  0.000041
# 2  MT0000011975  0.390880  0.134570 -1.123300  3.6591  0.62248  0.000818
# 3  MT0000040632  0.202410  0.078369 -0.513400  3.3213  0.41741  0.000351
# 4  MT0000044741  0.109260  0.071322  1.021700  3.2941  0.38580  0.000772
#
#      F0007    F0008   F0009  ...  VOICE-MELODY-RD-Contralto (F3-E5)  \
# 0  0.64696  0.64446  332.22  ...                            0.05000
# 1  0.43568  0.37822  252.78  ...                            0.57143
# 2  0.37552  0.18984  164.72  ...                            0.75000
# 3  0.43880  0.21232  211.14  ...                            0.80000
# 4  0.60699  0.53289  228.27  ...                            0.20690
#
#    VOICE-MELODY-RD-Tenor (B2-A4)  VOICE-MELODY-RD-Baritone (G2-F4)  \
# ...
