# %%
import pandas as pd

df1 = pd.read_csv(r'C:\Users\luboh\OneDrive\Área de Trabalho\USP\EngDadosBigData\eEDB-018_REPO\DEVELOPER\eEDB-018\prj\DATA\panda_dataset_taffc_annotations.csv')

df2  = pd.read_csv(r'C:\Users\luboh\OneDrive\Área de Trabalho\USP\EngDadosBigData\eEDB-018_REPO\DEVELOPER\eEDB-018\prj\DATA\panda_dataset_taffc_metadata.csv')

# %%
df1.head()
df2.head()
# Out:
#            Song                       Artist                            Title
# 0  MT0000004637                Charlie Poole  Bulldog Down in Sunny Tennessee  \
# 1  MT0000011357                    Dismember              Reborn in Blasphemy
# 2  MT0000011975  Curse of the Golden Vampire              Ultrasonic Meltdown
# 3  MT0000040632                  Gipsy Kings             Flamencos en el Aire
# 4  MT0000044741                Little Walter                       Last Night
#
#   Quadrant     PQuad  MoodsTotal  Moods
# 0       Q3  0.666667           3      3  \
# 1       Q2  0.666667           3      3
# 2       Q2  0.666667           6      5
# 3       Q1  0.750000           4      3
# 4       Q3  0.750000           4      4
#
#                                   MoodsFoundStr
# 0                       circular; greasy; messy  \
# 1                    jittery; negative; nervous
# 2  fierce; harsh; hostile; menacing; outrageous
# 3                            fiery; sexy; spicy
# ...
